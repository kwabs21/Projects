# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c08dc42f-d67c-4344-a712-f939d95f7dd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c08dc42f-d67c-4344-a712-f939d95f7dd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

data = pd.read_csv(io.BytesIO(uploaded['sensor_tweaked.csv']))
data
# Out:
#         sensor_00  sensor_13  sensor_18  sensor_34  sensor_35  sensor_48  \
# 0        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 1        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 2        2.444734   1.708474   2.500062   169.9820   343.1955   155.9606
# 3        2.460474   1.579427   2.509521   166.4987   343.9586   155.9606
# 4        2.445718   1.683831   2.604785   164.7498   339.9630   158.2755
# ...           ...        ...        ...        ...        ...        ...
# 220315   2.407350  13.265320   2.499117   266.0334   578.5221   212.3843
# 220316   2.400463  13.242270   2.618476   262.2222   568.1035   213.8310
# 220317   2.396528  13.188660   2.620500   260.8372   553.8872   217.3032
# 220318   2.406366  13.173460   2.514596   261.3184   559.4439   222.5116
# 220319   2.396528  13.125930   2.487299   258.4387   558.0558   227.4306
#
#         sensor_49  sensor_50  sensor_51 machine_status
# ...

# %%
data.interpolate(inplace=True)

# %%
data.isnull().values.any()
# Out:
# False

# %%
m = {'NORMAL': 'Normal', 'RECOVERING': 'Leak', 'BROKEN': 'Leak'}
data['pump_status'] = data['machine_status'].map(m)
data['pump_status']
# Out:
# 0         Normal
# 1         Normal
# 2         Normal
# 3         Normal
# 4         Normal
#            ...
# 220315    Normal
# 220316    Normal
# 220317    Normal
# 220318    Normal
# 220319    Normal
# Name: pump_status, Length: 220320, dtype: object

# %%
pd.concat([data, data['pump_status']])
# Out:
#         sensor_00  sensor_13  sensor_18  sensor_34  sensor_35  sensor_48  \
# 0        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 1        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 2        2.444734   1.708474   2.500062   169.9820   343.1955   155.9606
# 3        2.460474   1.579427   2.509521   166.4987   343.9586   155.9606
# 4        2.445718   1.683831   2.604785   164.7498   339.9630   158.2755
# ...           ...        ...        ...        ...        ...        ...
# 220315        NaN        NaN        NaN        NaN        NaN        NaN
# 220316        NaN        NaN        NaN        NaN        NaN        NaN
# 220317        NaN        NaN        NaN        NaN        NaN        NaN
# 220318        NaN        NaN        NaN        NaN        NaN        NaN
# 220319        NaN        NaN        NaN        NaN        NaN        NaN
#
#         sensor_49  sensor_50  sensor_51 machine_status pump_status       0
# ...

# %%
data
# Out:
#         sensor_00  sensor_13  sensor_18  sensor_34  sensor_35  sensor_48  \
# 0        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 1        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 2        2.444734   1.708474   2.500062   169.9820   343.1955   155.9606
# 3        2.460474   1.579427   2.509521   166.4987   343.9586   155.9606
# 4        2.445718   1.683831   2.604785   164.7498   339.9630   158.2755
# ...           ...        ...        ...        ...        ...        ...
# 220315   2.407350  13.265320   2.499117   266.0334   578.5221   212.3843
# 220316   2.400463  13.242270   2.618476   262.2222   568.1035   213.8310
# 220317   2.396528  13.188660   2.620500   260.8372   553.8872   217.3032
# 220318   2.406366  13.173460   2.514596   261.3184   559.4439   222.5116
# 220319   2.396528  13.125930   2.487299   258.4387   558.0558   227.4306
#
#         sensor_49  sensor_50  sensor_51 machine_status pump_status
# ...

# %%
data.drop('machine_status', axis=1, inplace=True)

# %%
data
# Out:
#         sensor_00  sensor_13  sensor_18  sensor_34  sensor_35  sensor_48  \
# 0        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 1        2.465394   1.681353   2.565284   171.9375   341.9039   157.9861
# 2        2.444734   1.708474   2.500062   169.9820   343.1955   155.9606
# 3        2.460474   1.579427   2.509521   166.4987   343.9586   155.9606
# 4        2.445718   1.683831   2.604785   164.7498   339.9630   158.2755
# ...           ...        ...        ...        ...        ...        ...
# 220315   2.407350  13.265320   2.499117   266.0334   578.5221   212.3843
# 220316   2.400463  13.242270   2.618476   262.2222   568.1035   213.8310
# 220317   2.396528  13.188660   2.620500   260.8372   553.8872   217.3032
# 220318   2.406366  13.173460   2.514596   261.3184   559.4439   222.5116
# 220319   2.396528  13.125930   2.487299   258.4387   558.0558   227.4306
#
#         sensor_49  sensor_50  sensor_51 pump_status
# ...

# %%
data.sample(frac=1, random_state=42)
# Out:
#         sensor_00  sensor_13  sensor_18  sensor_34  sensor_35  sensor_48  \
# 108145   2.499826   2.188541   2.598168   320.1235   469.9010   81.01852
# 185819   2.503762  14.407210   2.603111   242.5766   608.3739  190.10420
# 150648   2.510648  17.749490   2.574863   368.0821   549.9135  184.89580
# 216878   2.404398  13.057080   2.464594   222.9529   502.7404  426.50460
# 199813   2.400463  22.202180   2.547501   193.0003   508.5333  192.70830
# ...           ...        ...        ...        ...        ...        ...
# 119879   2.510648   0.823710   2.524223   314.3795   460.1342   62.78935
# 103694   2.459491   0.650733   2.429865   334.4460   481.9268   95.48611
# 131932   0.058163   0.000000   2.649260   368.9770   527.7963   31.82870
# 146867   2.503762   1.931578   2.581561   357.7942   519.3430  144.96530
# 121958   2.021701   0.481964   2.249803   256.6783   500.9055   98.95834
#
#         sensor_49    sensor_50  sensor_51 pump_status
# ...

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1]

# %%
x = (x - np.min(x)) / (np.max(x) - np.min(x))
x
# Out:
# array([[0.00246539, 0.00168135, 0.00256528, ..., 0.06770834, 0.2430556 ,
#         0.2013889 ],
#        [0.00246539, 0.00168135, 0.00256528, ..., 0.06770834, 0.2430556 ,
#         0.2013889 ],
#        [0.00244473, 0.00170847, 0.00250006, ..., 0.06712963, 0.2413194 ,
#         0.2037037 ],
#        ...,
#        [0.00239653, 0.01318866, 0.0026205 , ..., 0.1553819 , 1.        ,
#         0.2320602 ],
#        [0.00240637, 0.01317346, 0.0025146 , ..., 0.1539352 , 1.        ,
#         0.2340856 ],
#        [0.00239653, 0.01312593, 0.0024873 , ..., 0.150463  , 1.        ,
#         0.2340856 ]])

# %%
from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
y = lab.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Create loocv procedure
cv = LeaveOneOut()

# %%
# Create model
model = RandomForestClassifier(random_state=42)

# %%
# Evaluate model
scores = cross_val_score(model, x, y, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
# report performance
print('Accuracy: %.3f (%.3f)' % (mean(scores)), std(scores))
